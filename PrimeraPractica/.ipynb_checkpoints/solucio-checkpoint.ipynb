# %% [markdown]
# # Pràctica 1 - El procés de l'aprenentatge automàtic {-}

# %% [markdown]
# **Autors:**  Marc Melia Flexas y Martin Mitrovski Delov

# %% [markdown]
# ## Taula de continguts {-}
#
#  1. [Introducció](#introduccio)
#  2. [Tractament de dades](#tractament)
#  3. [Experiments realitzats](#experiments)
#  4. [Anàlisi dels resultats](#analisi)

# %% [markdown]
# # Introducció {#introduccio}
#
# El projecte...jhkjhkj
#
# El conjunt de dades que utilitzarem és Fashion Mnist
#
# **Fashion Mnist**
#
# Aquest conjunt de dades conté 70.000 imatges en escala de grisos en 10 categories. Les imatges mostren peces de roba individuals a baixa resolució (28 per 28 píxels). Fashion MNIST està pensat com una evolució directa del conjunt de dades clàssic MNIST que conté digits escrit a mà. Utilitzarem Fashion MNIST perquè presenta un problema una mica més difícil que el MNIST normal. Tots dos conjunts de dades són relativament petits i s'utilitzen per verificar que un algorisme funciona com s'esperava. Són bons punts de partida per provar i depurar codi, el que es coneix com a base line.

# %% [markdown]
# ## Libreries utilitzades

# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import scipy.stats

from scipy.stats import uniform, loguniform,expon, reciprocal
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from skimage import feature
from sklearn.model_selection import cross_val_score, KFold

from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA

from os.path import exists

# %% [markdown]
# # Tractament de dades {#tractament}

# %%
# Carregam el conjunt de dades
train = pd.read_csv('/home/mflexas/Escritorio/fashion-mnist_train.csv')
test = pd.read_csv('/home/mflexas/Escritorio/fashion-mnist_test.csv')



# Separam el conjunt d'entrenament en característiques X_train i etiquetes Y_train
X_train= train.drop(['label'],axis = 1)
y_train = train['label']

# Separam el conjunt de test en característiques X_train i etiquetes Y_train
X_test= test.drop(['label'],axis = 1)
y_test = test['label']

#Normalizar los valores de píxeles dividiéndolos por 255.0

X_train= X_train.astype('float32')
X_test = X_test.astype('float32')

X_train/= 255.0
X_test /= 255.0



conteo_por_clase = y_train.value_counts()

# Imprimir el número de instancias por clase
print("Número de instancias por clase en Fashion MNIST:")
print(conteo_por_clase)  


# Reducir el tamaño de datos
X_train_original, X_train_reduced, y_train_original, y_train_reduced = train_test_split(
    X_train, y_train, test_size=0.30, stratify=y_train, random_state=42
)



conteo_por_clase1 = y_train_reduced.value_counts()

# Imprimir el número de instancias por clase
print("Número de instancias por clase reduced en Fashion MNIST:")
print(conteo_por_clase1)  


# Dimensió del conjunt de característiques
print(X_train.shape)

# Dimensió de les etiquetes
print(y_train.shape)

print(X_test.shape)

print(y_test.shape)
# Out:
# Número de instancias por clase en Fashion MNIST:
# label
# 2    6000
# 9    6000
# 6    6000
# 0    6000
# 3    6000
# 4    6000
# 5    6000
# 8    6000
# 7    6000
# 1    6000
# Name: count, dtype: int64
# Número de instancias por clase reduced en Fashion MNIST:
# label
# 7    1800
# 1    1800
# 5    1800
# 3    1800
# 4    1800
# 9    1800
# 0    1800
# 2    1800
# 8    1800
# 6    1800
# Name: count, dtype: int64
# (60000, 784)
# (60000,)
# (10000, 784)
# (10000,)

# %%
# Función para aplicar LBP a una imagen
def apply_lbp(image):
    # Ajustar la forma de la imagen a (28, 28) si es necesario
    image = np.array(image).reshape(28, 28)
    

    # Aplicar LBP a la imagen
    lbp_image = feature.local_binary_pattern(image, P=24, R=3)

    # Aplanar la imagen LBP
    lbp_image_flat = lbp_image.flatten()
    
    #print(lbp_image_flat)

    return lbp_image_flat

# Aplicar LBP a todas las imágenes de entrenamiento y prueba
X_train_lbp = np.array([apply_lbp(image) for image in X_train.values])
X_test_lbp = np.array([apply_lbp(image) for image in X_test.values])

# Verificar las nuevas formas
print("Forma original de X_train:", X_train.shape)
print("Forma de X_train después de aplicar LBP:", X_train_lbp.shape)

#X_train_lbp /= 255.0
#X_val /= 255.0
#X_test_lbp /= 255.0

print(X_train_lbp)

print(X_train_lbp[0][0])


# Ahora puedes utilizar X_train_lbp y X_test_lbp en lugar de X_train y X_test en tu modelo SVM
# Out:
# Forma original de X_train: (60000, 784)
# Forma de X_train después de aplicar LBP: (60000, 784)
# [[16777215. 16777215. 16777215. ... 16777215. 16777215. 16777215.]
#  [16777215. 16777215. 16777215. ... 16777215. 16777215. 16777215.]
#  [16777215. 16777215. 16777215. ... 16777215. 16777215. 16777215.]
#  ...
#  [16777215. 16777215. 16777215. ... 16777215. 16777215. 16777215.]
#  [16777215. 16777215. 16777215. ... 16777215. 16777215. 16777215.]
#  [16777215. 16777215. 16777215. ... 16777215. 16777215. 16777215.]]
# 16777215.0

# %%
def apply_hog(image):
    # Ajustar la forma de la imagen a (28, 28) si es necesario
    image = np.array(image).reshape(28, 28)

    # Calcular las características HOG
    hog_features, hog_image = feature.hog(image, orientations=8, pixels_per_cell=(4, 4),
                                          cells_per_block=(1, 1), visualize=True)

    # Aplanar las características HOG
    hog_features_flat = hog_features.flatten()

    return hog_features_flat


X_train_hog = np.array([apply_hog(image) for image in X_train.values])
X_test_hog = np.array([apply_hog(image) for image in X_test.values])

# Verificar las nuevas formas
print("Forma original de X_train:", X_train.shape)
print("Forma de X_train después de aplicar LBP:", X_train_hog.shape)
# Out:
# Forma original de X_train: (60000, 784)
# Forma de X_train después de aplicar LBP: (60000, 392)

# %%
#PCA
# Especificar el número de componentes principales que deseas retener
n_components = 0.90  # Ajusta según tus necesidades

# Inicializar PCA
pca = PCA(n_components=n_components)

# Ajustar y transformar los datos de entrenamiento
X_train_pca = pca.fit_transform(X_train_reduced)

# Transformar los datos de prueba (usando los mismos componentes principales aprendidos del conjunto de entrenamiento)
X_test_pca = pca.transform(X_test)

print(X_train_pca.shape)
print(X_test_pca.shape)

print(X_train_pca)
print(X_test_pca)
# Out:
# (18000, 83)
# (10000, 83)
# [[-5.97688006e+00  2.16273694e+00 -5.65010423e-01 ...  1.67767894e-01
#   -4.74535012e-02 -2.62286017e-01]
#  [ 1.13077640e+00 -4.90605162e+00  6.76150718e-01 ...  2.87043355e-01
#   -2.23063302e-01 -2.53299828e-01]
#  [-7.03865656e+00 -1.14995089e+00 -2.29464091e+00 ... -2.30319374e-01
#    5.02415601e-02  2.24180973e-01]
#  ...
#  [ 4.14837738e-01 -5.85853227e+00  1.68431673e+00 ...  1.89853565e-01
#   -3.74803215e-01  9.45120647e-02]
#  [ 5.07983517e+00 -2.24735892e+00  1.09993693e+00 ...  2.56740434e-01
#    3.26480177e-02  3.44425884e-02]
#  [-7.19689397e+00 -8.12542875e-03 -6.75320534e-01 ... -5.57074820e-04
#   -2.33972642e-01 -2.38129544e-01]]
# [[ 5.40547515 -1.54955858  0.82653857 ...  0.21425348  0.1657668
#   -0.01120405]
#  [-0.35422024 -6.10097568  1.21850729 ... -0.10999739 -0.12987288
#   -0.32864098]
#  [-3.24760298 -0.5469462  -3.27469023 ... -0.05561535 -0.09897152
#    0.12443158]
#  ...
# ...

# %% [markdown]
# # Experiments realitzats {#experiments}
#
# ## Experiment 1
#
# En el primer experiment que volem realizar volem veure quin és el resultat d'utilitzar un SVM amb els paràmetres per defecte, sense modificarne cap. Els paràmetres per defecte de la classe SVC de la llibreria sklear son els seguents:
#
# SVC(C=1.0, kernel='rbf', degree=3, gamma='scale', coef0=0.0, shrinking=True, probability=False, tol=1e-3, cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape='ovr', break_ties=False, random_state=None)
#
# -sense normalitzar

# %%
# Iniciar el temporizador antes de entrenar el modelo
start_time = time.time()

# Inicializar el clasificador SVM
svm_classifier = SVC()

# Entrenar el modelo SVM
svm_classifier.fit(X_train_reduced, y_train_reduced)

# Detener el temporizador después de entrenar el modelo
end_time = time.time()

# Calcular el tiempo transcurrido
elapsed_time = end_time - start_time
print(f"Tiempo de entrenamiento: {elapsed_time} segundos")

y_test_pred = svm_classifier.predict(X_test)
    
# Evaluar el rendimiento en el conjunto de test
accuracy = accuracy_score(y_test, y_test_pred)
print(f"Accuracy on test set: {accuracy}")

# Calcular y mostrar el classification report que incluye F1-score
print("Classification Report:")
print(classification_report(y_test, y_test_pred))

conf_matrix = confusion_matrix(y_test, y_test_pred)

# Visualizar la matriz de confusión con matplotlib
plt.figure(figsize=(10, 8))
plt.imshow(conf_matrix, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Matriz de Confusión')
plt.colorbar()

classes = np.unique(y_test)
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

plt.xlabel('Predicciones')
plt.ylabel('Valores Verdaderos')

for i in range(len(classes)):
    for j in range(len(classes)):
        plt.text(j, i, str(conf_matrix[i, j]), horizontalalignment='center', verticalalignment='center')

plt.show()
# Out:
# Tiempo de entrenamiento: 16.059610605239868 segundos
# Accuracy on test set: 0.8731
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.85      0.82      1000
#            1       0.99      0.96      0.98      1000
#            2       0.80      0.81      0.80      1000
#            3       0.86      0.92      0.89      1000
#            4       0.82      0.83      0.83      1000
#            5       0.95      0.92      0.94      1000
#            6       0.72      0.62      0.67      1000
#            7       0.91      0.91      0.91      1000
#            8       0.95      0.96      0.96      1000
#            9       0.92      0.94      0.93      1000
#
#     accuracy                           0.87     10000
#    macro avg       0.87      0.87      0.87     10000
# weighted avg       0.87      0.87      0.87     10000

# %% [markdown]
# Explicar resultats experiment 1

# %% [markdown]
# ## Experiment 2
#
# GridSearch
#
# KFold

# %%
# Definir el clasificador SVM con kernel lineal
svm_classifier = SVC(kernel='linear')

# Definir el espacio de búsqueda para los hiperparámetros
param_dist = {
    'C': reciprocal(0.01, 100),  # Parámetro de regularización
}

# Crear el objeto RandomizedSearchCV con StratifiedKFold
random_search = RandomizedSearchCV(
    svm_classifier,
    param_distributions=param_dist,
    n_iter=100,  # Número de combinaciones aleatorias a probar
    scoring='accuracy',  # Puedes cambiar la métrica según tus necesidades
    cv=3, # Usar StratifiedKFold en lugar de KFold
    n_jobs=-1,
    verbose=1
)

# Realizar la búsqueda aleatoria
random_search.fit(X_train_pca, y_train_reduced)

# Obtener los resultados como un DataFrame
results_df = pd.DataFrame(random_search.cv_results_)

# Nombre del archivo CSV
csv_filename = 'random_search_lineal_pca.csv'

# Intentar cargar el archivo CSV existente (si existe)
if exists(csv_filename):
    existing_results_df = pd.read_csv(csv_filename)
else:
    existing_results_df = pd.DataFrame()

# Concatenar los resultados existentes con los nuevos resultados
results_df_combined = pd.concat([existing_results_df, results_df], ignore_index=True)

# Guardar los resultados combinados en un archivo CSV
results_df_combined.to_csv(csv_filename, index=False)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Fitting 3 folds for each of 100 candidates, totalling 300 fits

# %%
# Cargar el archivo CSV con los resultados del RandomizedSearchCV
df = pd.read_csv('random_search_lineal_pca.csv')  # Reemplaza 'ruta_del_archivo.csv' con la ubicación real de tu archivo CSV

# Ordenar el DataFrame por la columna de precisión en orden descendente
df_sorted = df.sort_values(by='mean_test_score', ascending=False)

# Mostrar los 10 primeros resultados

top_10_results = df_sorted[['params', 'mean_test_score']]
top_10_results = top_10_results.head(10)

# Imprimir los resultados
print(top_10_results)
# Out:
#                          params  mean_test_score
# 120  {'C': 0.12145224285992819}         0.854867
# 82   {'C': 0.12198015016387172}         0.854867
# 20   {'C': 0.11909339542542018}         0.854600
# 8     {'C': 0.0697902627672176}         0.854400
# 131  {'C': 0.10119683372754586}         0.854333
# 152  {'C': 0.10107610987438403}         0.854200
# 71   {'C': 0.10996197361754365}         0.854067
# 117   {'C': 0.1745045076739379}         0.854000
# 145  {'C': 0.16055306216358278}         0.853867
# 106  {'C': 0.11222011786413316}         0.853800

# %%
# Seleccionar solo las columnas 'param_C' y 'mean_test_score'
resultados_seleccionados = df[['param_C', 'mean_test_score']].copy()  # Hacer una copia explícita

# Convertir el parámetro C a valores numéricos
resultados_seleccionados['param_C'] = resultados_seleccionados['param_C'].astype(float)

# Ordenar el DataFrame por el valor de C
resultados_ordenados = resultados_seleccionados.sort_values(by='param_C')

# Trazar la relación entre C y la precisión media
plt.figure(figsize=(10, 6))
plt.plot(resultados_ordenados['param_C'], resultados_ordenados['mean_test_score'], marker='o')
plt.xscale('log')  # Escala logarítmica para C
plt.xlabel('Valor de C')
plt.ylabel('Acuracy')
plt.title('Relación entre C y Acuracy')
plt.grid(True)
plt.show()



# Seleccionar las columnas relevantes
resultados_seleccionados = df[['param_C', 'mean_fit_time']].copy()  # Hacer una copia explícita

# Convertir el parámetro C a valores numéricos
resultados_seleccionados['param_C'] = resultados_seleccionados['param_C'].astype(float)

# Ordenar el DataFrame por el valor de C
resultados_ordenados = resultados_seleccionados.sort_values(by='param_C')

# Trazar la relación entre C y el tiempo de ajuste
plt.figure(figsize=(10, 6))
plt.plot(resultados_ordenados['param_C'], resultados_ordenados['mean_fit_time'], marker='s', color='blue')
plt.xscale('log')  # Escala logarítmica para C
plt.xlabel('Valor de C')
plt.ylabel('Tiempo de Ajuste (s)')
plt.title('Relación entre C y Tiempo de Ajuste')
plt.grid(True)
plt.show()

# %%
# Calcular gamma para 'scale'
gamma_scale = 1 / (X_train_pca.shape[1] * X_train_pca.var())

# Calcular gamma para 'auto'
gamma_auto = 1 / X_train_pca.shape[1]

# Imprimir los resultados
print("Gamma para 'scale':", gamma_scale)
print("Gamma para 'auto':", gamma_auto)
# Out:
# Gamma para 'scale': 0.016305638838362536
# Gamma para 'auto': 0.011904761904761904

# %%
# Definir el clasificador SVM con kernel lineal
svm_classifier = SVC(kernel='rbf')

# Definir el espacio de búsqueda para los hiperparámetros
param_dist_rbf = {
   'C': reciprocal(0.01, 1000),
   'gamma': reciprocal(0.001, 0.1)
}

# Crear el objeto RandomizedSearchCV con StratifiedKFold
random_search = RandomizedSearchCV(
    svm_classifier,
    param_distributions=param_dist_rbf,
    n_iter=100,  # Número de combinaciones aleatorias a probar
    scoring='accuracy',  # Puedes cambiar la métrica según tus necesidades
    cv=5, # Usar StratifiedKFold en lugar de KFold
    n_jobs=-1,
    verbose=1
)

# Realizar la búsqueda aleatoria
random_search.fit(X_train_pca, y_train_reduced)

# Obtener los resultados como un DataFrame
results_df = pd.DataFrame(random_search.cv_results_)

# Nombre del archivo CSV
csv_filename = 'random_search_rbf_pca.csv'

# Intentar cargar el archivo CSV existente (si existe)
if exists(csv_filename):
    existing_results_df = pd.read_csv(csv_filename)
else:
    existing_results_df = pd.DataFrame()

# Concatenar los resultados existentes con los nuevos resultados
results_df_combined = pd.concat([existing_results_df, results_df], ignore_index=True)

# Guardar los resultados combinados en un archivo CSV
results_df_combined.to_csv(csv_filename, index=False)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits

# %%
# Cargar el archivo CSV con los resultados del RandomizedSearchCV para el kernel RBF
df_rbf = pd.read_csv('random_search_rbf_pca.csv')  # Reemplaza 'ruta_del_archivo.csv' con la ubicación real de tu archivo CSV

# Ordenar el DataFrame por la columna de precisión en orden descendente
df_rbf_sorted = df_rbf.sort_values(by='mean_test_score', ascending=False)

# Mostrar los 10 primeros resultados
top_10_results_rbf = df_rbf_sorted[['params', 'mean_test_score']]
top_10_results_rbf = top_10_results_rbf.head(10)

# Imprimir los resultados
print(top_10_results_rbf)
# Out:
#                                                 params  mean_test_score
# 100  {'C': 5.654431097668237, 'gamma': 0.0272042078...         0.882833
# 72   {'C': 2.4128108867488613, 'gamma': 0.059547317...         0.881500
# 67   {'C': 14.660205836605984, 'gamma': 0.017711236...         0.880611
# 75   {'C': 7.742029055533687, 'gamma': 0.0511069363...         0.880444
# 11   {'C': 17.929621477653605, 'gamma': 0.016303425...         0.880056
# 83   {'C': 24.935157554393964, 'gamma': 0.015359829...         0.879944
# 43   {'C': 19.054659961456483, 'gamma': 0.012333798...         0.879889
# 71   {'C': 13.835661362533608, 'gamma': 0.024916012...         0.879833
# 48   {'C': 2.0961272357628387, 'gamma': 0.084885458...         0.879556
# 52   {'C': 20.01753354704938, 'gamma': 0.0228128134...         0.879556

# %%
import numpy as np
import matplotlib.pyplot as plt

# Supongamos que df_rbf_sorted es tu DataFrame

# Obtén los valores únicos de C y gamma y ordénalos
unique_C = np.sort(df_rbf_sorted['param_C'].unique())
unique_gamma = np.sort(df_rbf_sorted['param_gamma'].unique())

# Crea el heatmap
scores = np.array(df_rbf_sorted['mean_test_score']).reshape(len(unique_C), -1)
plt.imshow(scores, cmap='viridis', interpolation='nearest', aspect='auto')

# Configura los ticks en los ejes x e y para que muestren el rango de valores
plt.xticks(np.arange(len(unique_gamma)), unique_gamma, rotation=45)
plt.yticks(np.arange(len(unique_C)), unique_C)

plt.xlabel('Gamma')
plt.ylabel('C')
plt.colorbar(label='Precisión (mean_test_score)')
plt.title('Heatmap de Precisión para SVM con Kernel RBF')
plt.show()

# %%
# Seleccionar las columnas relevantes y hacer una copia explícita
resultados_seleccionados_rbf = df_rbf[['param_C', 'mean_test_score']].copy()

# Convertir el parámetro C a valores numéricos
resultados_seleccionados_rbf['param_C'] = pd.to_numeric(resultados_seleccionados_rbf['param_C'], errors='coerce')

# Eliminar filas con valores no numéricos en param_C
resultados_seleccionados_rbf = resultados_seleccionados_rbf.dropna(subset=['param_C'])

# Filtrar valores de C en el rango de 0.1 a 100
resultados_filtrados = resultados_seleccionados_rbf[(resultados_seleccionados_rbf['param_C'] >= 0.1) & (resultados_seleccionados_rbf['param_C'] <= 100)]

# Crear un gráfico de dispersión
plt.figure(figsize=(10, 6))
plt.scatter(resultados_filtrados['param_C'], resultados_filtrados['mean_test_score'], c='blue', marker='o')
plt.xscale('log')  # Escala logarítmica para C
plt.xlabel('Valor de C (escala logarítmica)')
plt.ylabel('Precisión Media')
plt.title('Relación entre C y Precisión Media (kernel RBF)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Seleccionar las columnas relevantes y hacer una copia explícita
# ----> 2 resultados_seleccionados_rbf = df_rbf[['param_C', 'param_gamma', 'mean_test_score']].copy()
#       4 # Convertir el parámetro C a valores numéricos
#       5 resultados_seleccionados_rbf['param_C'] = pd.to_numeric(resultados_seleccionados_rbf['param_C'], errors='coerce')
#
# NameError: name 'df_rbf' is not defined

# %%
# Seleccionar las columnas relevantes y hacer una copia explícita
resultados_seleccionados_rbf = df_rbf[['param_C', 'param_gamma', 'mean_test_score']].copy()

# Crear un gráfico de dispersión
plt.figure(figsize=(10, 6))

# Filtrar por gamma 'scale'
mask_scale = resultados_seleccionados_rbf['param_gamma'] == 'scale'
plt.scatter(resultados_seleccionados_rbf[mask_scale]['param_gamma'], resultados_seleccionados_rbf[mask_scale]['mean_test_score'], color='red', label='Gamma: scale')

# Filtrar por gamma 'auto'
mask_auto = resultados_seleccionados_rbf['param_gamma'] == 'auto'
plt.scatter(resultados_seleccionados_rbf[mask_auto]['param_gamma'], resultados_seleccionados_rbf[mask_auto]['mean_test_score'], color='blue', label='Gamma: auto')

# Filtrar por valores numéricos de gamma
gamma_numerico = resultados_seleccionados_rbf['param_gamma'].apply(lambda x: float(x) if x.replace('.', '', 1).isdigit() else None)
mask_numerico = gamma_numerico.notnull()
plt.scatter(resultados_seleccionados_rbf[mask_numerico]['param_gamma'], resultados_seleccionados_rbf[mask_numerico]['mean_test_score'], color='green', label='Gamma: numérico')

# Configuración del gráfico
plt.xlabel('Valor de Gamma')
plt.ylabel('Precisión Media')
plt.title('Efecto de Gamma en el Modelo RBF-SVM')
plt.legend()
plt.show()

# %%
# Definir los parámetros y los valores a probar
param_grid = {'C': [0.1, 1, 10, 100], 
              'kernel': ['linear', 'rbf', 'poly','sigmoid'], 
              'gamma': ['scale', 'auto']}

# Inicializar el clasificador  SVM
svm_classifier = SVC()  

# Inicializar GridSearchCV con el clasificador y los parámetros a probar
grid_search = GridSearchCV(estimator=svm_classifier, param_grid=param_grid, cv=5)

# Iniciar el temporizador antes de entrenar el modelo
start_time = time.time()

# Realizar la búsqueda de cuadrícula en los datos
grid_search.fit(X_train_pca, y_train)

# Detener el temporizador después de entrenar el modelo
end_time = time.time()

# Calcular el tiempo transcurrido
elapsed_time = end_time - start_time
print(f"Tiempo de entrenamiento: {elapsed_time} segundos")

# Imprimir los mejores parámetros y el mejor rendimiento
print("Mejores parámetros:", grid_search.best_params_)
print("Mejor rendimiento (accuracy):", grid_search.best_score_)

# Obtener el mejor clasificador entrenado
best_classifier = grid_search.best_estimator_

# Realizar predicciones en el conjunto de prueba
y_pred = best_classifier.predict(X_test_pca)

# Evaluar el rendimiento en el conjunto de test
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy on test set: {accuracy}")

# %%
# Definir los parámetros y los valores a probar
param_grid = {'C': [0.1, 1], 
              'kernel': ['linear', 'rbf'], 
              'gamma': [0.1, 1]}

# Inicializar el clasificador  SVM
svm_classifier = SVC()  

# Inicializar GridSearchCV con el clasificador y los parámetros a probar
grid_search = GridSearchCV(estimator=svm_classifier, param_grid=param_grid, cv=5, n_jobs=-1)

# Iniciar el temporizador antes de entrenar el modelo
start_time = time.time()

# Realizar la búsqueda de cuadrícula en los datos
grid_search.fit(X_train_pca, y_train)

# Detener el temporizador después de entrenar el modelo
end_time = time.time()

# Calcular el tiempo transcurrido
elapsed_time = end_time - start_time
print(f"Tiempo de entrenamiento: {elapsed_time} segundos")

# Imprimir los mejores parámetros y el mejor rendimiento
print("Mejores parámetros:", grid_search.best_params_)
print("Mejor rendimiento (accuracy):", grid_search.best_score_)

# Obtener el mejor clasificador entrenado
best_classifier = grid_search.best_estimator_

# Realizar predicciones en el conjunto de prueba
y_pred = best_classifier.predict(X_test_pca)

# Evaluar el rendimiento en el conjunto de test
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy on test set: {accuracy}")

# %% [markdown]
# ## Experiment 3
#
# PCA

# %% [markdown]
# ## Experiment 4

# %% [markdown]
# HOP

# %% [markdown]
# # Anàlisi dels resultats {#analisi}
#
# asdasdasdasd m,
